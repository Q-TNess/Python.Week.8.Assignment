# %% [markdown]
# # Loading the dataset

# %%
import pandas as pd

df = pd.read_csv('data.csv')

# Displaying 7 rows

df.head(7)
# Out:
#    Bankrupt?   ROA(C) before interest and depreciation before interest  \
# 0          1                                           0.370594
# 1          1                                           0.464291
# 2          1                                           0.426071
# 3          1                                           0.399844
# 4          1                                           0.465022
# 5          1                                           0.388680
# 6          0                                           0.390923
#
#     ROA(A) before interest and % after tax  \
# 0                                 0.424389
# 1                                 0.538214
# 2                                 0.499019
# 3                                 0.451265
# 4                                 0.538432
# 5                                 0.415177
# 6                                 0.445704
#
#     ROA(B) before interest and depreciation after tax  \
# ...

# %%
# checking data types
df.dtypes
# Out:
# Bankrupt?                                                     int64
#  ROA(C) before interest and depreciation before interest    float64
#  ROA(A) before interest and % after tax                     float64
#  ROA(B) before interest and depreciation after tax          float64
#  Operating Gross Margin                                     float64
#                                                              ...
#  Liability to Equity                                        float64
#  Degree of Financial Leverage (DFL)                         float64
#  Interest Coverage Ratio (Interest expense to EBIT)         float64
#  Net Income Flag                                              int64
#  Equity to Liability                                        float64
# Length: 96, dtype: object

# %%
# checking missing values
df.isnull().sum()
# Out:
# Bankrupt?                                                   0
#  ROA(C) before interest and depreciation before interest    0
#  ROA(A) before interest and % after tax                     0
#  ROA(B) before interest and depreciation after tax          0
#  Operating Gross Margin                                     0
#                                                            ..
#  Liability to Equity                                        0
#  Degree of Financial Leverage (DFL)                         0
#  Interest Coverage Ratio (Interest expense to EBIT)         0
#  Net Income Flag                                            0
#  Equity to Liability                                        0
# Length: 96, dtype: int64

# %% [markdown]
# ### There are no missing values in the data however a column will be added and dropped for demonstration purposes, and the data will be cleaned by removing white space

# %%
# REMOVING WHITE SPACE
df.columns = df.columns.str.strip()
# ADDING A TOTAL COLUMN
df['Total']= df['Operating Gross Margin'] + df['Realized Sales Gross Margin'] + df['Operating Profit Rate'] + df['Pre-tax net Interest Rate'] + df['After-tax net Interest Rate'] + df['Gross Profit to Sales']

# DROPPING THE TOTAL COLUMN
df = df.drop(columns=['Total'])
df
# Out:
#       Bankrupt?  ROA(C) before interest and depreciation before interest  \
# 0             1                                           0.370594
# 1             1                                           0.464291
# 2             1                                           0.426071
# 3             1                                           0.399844
# 4             1                                           0.465022
# ...         ...                                                ...
# 6814          0                                           0.493687
# 6815          0                                           0.475162
# 6816          0                                           0.472725
# 6817          0                                           0.506264
# 6818          0                                           0.493053
#
#       ROA(A) before interest and % after tax  \
# 0                                   0.424389
# 1                                   0.538214
# ...

# %% [markdown]
# # **TASK 2**

# %%
#  basic statistics of the numerical columns 
df.describe()
# Out:
#          Bankrupt?   ROA(C) before interest and depreciation before interest  \
# count  6819.000000                                        6819.000000
# mean      0.032263                                           0.505180
# std       0.176710                                           0.060686
# min       0.000000                                           0.000000
# 25%       0.000000                                           0.476527
# 50%       0.000000                                           0.502706
# 75%       0.000000                                           0.535563
# max       1.000000                                           1.000000
#
#         ROA(A) before interest and % after tax  \
# count                              6819.000000
# mean                                  0.558625
# std                                   0.065620
# min                                   0.000000
# 25%                                   0.535543
# ...

# %%
df.sort_values(['Gross Profit to Sales','Bankrupt?',"Net Income to Stockholder's Equity",'Realized Sales Gross Margin'], ascending=False) #arranging in descending order
# Out:
#       Bankrupt?  ROA(C) before interest and depreciation before interest  \
# 2411          0                                           0.471165
# 379           1                                           0.453956
# 2459          0                                           0.596792
# 3086          0                                           0.449764
# 3095          0                                           0.402330
# ...         ...                                                ...
# 5033          0                                           0.203968
# 3221          0                                           0.423878
# 3845          0                                           0.301126
# 1578          0                                           0.428655
# 2490          0                                           0.412178
#
#       ROA(A) before interest and % after tax  \
# 2411                                0.543611
# 379                                 0.516082
# ...

# %%
# comparing the companies' bankrupcy based on their net interest rate
df[(df['Pre-tax net Interest Rate'] > 0.75)|(df['After-tax net Interest Rate'] > 0.75)].sort_values(by='Bankrupt?', ascending=False)
# Out:
#       Bankrupt?  ROA(C) before interest and depreciation before interest  \
# 0             1                                           0.370594
# 2148          1                                           0.439234
# 6640          1                                           0.196802
# 2908          1                                           0.446497
# 2907          1                                           0.430264
# ...         ...                                                ...
# 2355          0                                           0.473895
# 2354          0                                           0.480183
# 2353          0                                           0.496856
# 2352          0                                           0.475162
# 6818          0                                           0.493053
#
#       ROA(A) before interest and % after tax  \
# 0                                   0.424389
# 2148                                0.504416
# ...

# %% [markdown]
# ###  Findings from the analysis:
# #### Companies labeled as bankrupt (1) seem to have lower Pre-tax and After-tax interest Rates compared to bankrupt(0) companies

# %% [markdown]
# # **TASK 3**

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# STREAMS DATA OF BEYONCE'S VIDEO OVER THE YEARS 
years = [2011,2012,2015,2020,2025]
streams = [1100000,2000000,2000100,6200000,6300000]

# Line graph
plt.figure(figsize=(8,5))
sns.lineplot(x=years, y=streams, marker='o', color='purple')
plt.title("Video Streams over the Years (Line Chart)")
plt.xlabel("Year")
plt.ylabel("Streams")
plt.tight_layout()
plt.show()

# %%
# Bar graph
plt.figure(figsize=(8,5))
sns.barplot(x=years, y=streams, palette="Blues_d")
plt.title("Video Streams over the Years (Bar Chart)")
plt.xlabel("Year")
plt.ylabel("Streams")
plt.tight_layout()
plt.show()

# %%
# Histogram

plt.figure(figsize=(8,5))
plt.hist(streams, bins=10, color='purple', edgecolor='black')
plt.title('Distribution of Video Streams (Histogram)')
plt.xlabel('Number of Streams')
plt.ylabel('Frequency')
plt.tight_layout()
plt.show()

# %%
# Pie chart
plt.figure(figsize=(6,6))
plt.pie(streams, labels=years, autopct='%1.1f%%', startangle=140, colors=sns.color_palette("pastel"))
plt.title("Video Streams over the Years (Pie Chart)")
plt.axis('equal')
plt.show()

# %% [markdown]
# ### Error handling:

# %%
# Attempt to load data 
try:
    import csv

    years = []
    streams = []

    with open("beyonce_streams.csv", mode="r") as file:
        reader = csv.DictReader(file)
        for row in reader:
            try:
                year = int(row['year'])
                stream = int(row['streams'])
                years.append(year)
                streams.append(stream)
            except ValueError:
                print(f"Invalid data found and skipped: {row}")
except FileNotFoundError:
    print("File not found. Using default data.")
# Out:
# File not found. Using default data.
